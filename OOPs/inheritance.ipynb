# %% [markdown]
# ## Inheritance

# %%
#Parent class(Single Inheritance)
class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype
    
    def drive(self):
        print(f"The person is driving {self.enginetype} car.")

# %%
car1 = Car(4,5,"Petrol")
car1.drive()
# Out:
# The person is driving Petrol car.

# %%
#Child Class

class Tesla(Car):
    def __init__(self,windows,doors,enginetype,is_selfdriving):
        super().__init__(windows,doors,enginetype) #Super key help us to call the constructor of parent class
        self.is_selfdriving = is_selfdriving
    
    def selfdriving(self):
        print(f"Tesla is self driving : {self.is_selfdriving}")

# %%
tesla1 = Tesla(4,4,"electric",True)

tesla1.selfdriving()
tesla1.drive()
# Out:
# Tesla is self driving : True
# The person is driving electric car.

# %%
# Multiple Inheritance

class Animal:
    def __init__(self,name):
        self.name = name
    
    def speak(self):
        print(f"Subclass must implement this is function")

class Pet:
    def __init__(self,owner):
        self.owner = owner


class Dog(Animal,Pet):
    def __init__(self,name,owner):
        Animal.__init__(self,name)
        Pet.__init__(self,owner)

    def speak(self): 
        print(f"{self.name} says woof!")

# %%
dog = Dog("Lucy","Sumit")
dog.speak()
# Out:
# Lucy says woof!
