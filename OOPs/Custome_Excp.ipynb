# %% [markdown]
# ## Custome Error

# %%
class Err(Exception):
    pass

age = int(input("Enter your birth year"))

try:
    if 2026-age >= 20 :
        print("Your are eligible")
    else :
        raise Err
except Err:
    print("The age is not under limit")
# Out:
# The age is not under limit
