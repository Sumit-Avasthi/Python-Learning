# %%
import os

os.mkdir('package') # To create the new directory in the cwd

# %%
# To Listing the files and directory

print(os.listdir('.'))
# Out:
# ['Basics.ipynb', 'destination.txt', 'example.bin', 'package', 'test.txt', 'using_os.ipynb']

# %%
os.getcwd()
# Out:
# 'c:\\Udemy\\Python\\File_handling'

# %%
#It joins path components using the correct path separator:
dir_name="folder"
file_name="file"
os.path.join(dir_name,file_name)
# Out:
# 'folder\\file'

# %%
if os.path.exists('test.txt') :
    print("yes")
# Out:
# yes

# %%
if os.path.isfile('test.txt'):
    print("Hellow file")

if os.path.isdir('package'):
    print("Package is here baby")
# Out:
# Hellow file
# Package is here baby

# %%
# Getting the absolute path

print(os.path.abspath('test.txt'))
# Out:
# c:\Udemy\Python\File_handling\test.txt
