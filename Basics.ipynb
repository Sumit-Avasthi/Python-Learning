# %% [markdown]
# ## Memory management

# %% [markdown]
# ## Reference Count

# %%
import sys

# %%
a = []
print(sys.getrefcount(a))
# Out:
# 2

# %%
b = a
print(sys.getrefcount(a))
# Out:
# 3

# %%
del b
print(sys.getrefcount(a))
# Out:
# 2

# %% [markdown]
# ## Garbage collecgtor

# %%
import gc

# %%
gc.enable()

# %%
gc.collect()
# Out:
# 202

# %%
gc.disable()

# %%
gc.get_stats()
# Out:
# [{'collections': 191, 'collected': 1548, 'uncollectable': 0},
#  {'collections': 16, 'collected': 285, 'uncollectable': 0},
#  {'collections': 2, 'collected': 202, 'uncollectable': 0}]

# %%
gc.garbage
# Out:
# []
